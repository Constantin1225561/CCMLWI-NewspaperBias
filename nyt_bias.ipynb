# %%
import pandas as pd

# %%
headlines = pd.read_csv('headlines_nyt_test.csv',encoding='ansi',delimiter=';')

# %%
headlines
# Out:
#                                                            pub_date,web_url  \
# 2010-01-01T20:35:02Z      http://www.nytimes.com/slideshow/2010/01/01/wo...
# 2010-01-02T00:00:00Z      http://www.nytimes.com/2010/01/02/world/africa...
# 2010-01-08T00:00:00Z      http://www.nytimes.com/2010/01/08/us/08cncfami...
# 2010-01-09T00:00:00Z      http://www.nytimes.com/2010/01/09/opinion/l09r...
# 2010-01-12T00:00:00Z      http://www.nytimes.com/2010/01/12/opinion/lweb...
# 2010-01-17T00:00:00Z      http://www.nytimes.com/2010/01/17/opinion/17ne...
# 2010-01-19T00:00:00Z      http://www.nytimes.com/2010/01/19/us/19refugee...
# 2010-01-20T00:00:00Z      http://www.nytimes.com/2010/01/20/world/africa...
# 2010-01-23T00:00:00Z      http://www.nytimes.com/2010/01/23/world/europe...
# 2010-01-31T00:00:00Z      http://www.nytimes.com/2010/01/31/us/31sfsomal...
# 2010-01-31T00:00:00Z      http://www.nytimes.com/interactive/2010/01/31/...
# ...
